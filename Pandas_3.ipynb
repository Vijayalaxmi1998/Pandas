# %% [markdown]
# # Acessing Data from DataFrame

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv",skiprows=4)
olympic_data.head(1)
# Out:
#      City  Edition     Sport Discipline        Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming  HAJOS, Alfred  HUN    Men
#
#             Event Event_gender Medal
# 0  100m freestyle            M  Gold

# %% [markdown]
# ## Accessing column using []

# %%
olympic_data["Edition"]
# Out:
# 0        1896
# 1        1896
# 2        1896
# 3        1896
# 4        1896
#          ...
# 29211    2008
# 29212    2008
# 29213    2008
# 29214    2008
# 29215    2008
# Name: Edition, Length: 29216, dtype: int64

# %%
type(olympic_data["Edition"])
# Out:
# pandas.core.series.Series

# %%
olympic_data[["Edition","Sport","NOC"]]
# Out:
#        Edition      Sport  NOC
# 0         1896   Aquatics  HUN
# 1         1896   Aquatics  AUT
# 2         1896   Aquatics  GRE
# 3         1896   Aquatics  GRE
# 4         1896   Aquatics  GRE
# ...        ...        ...  ...
# 29211     2008  Wrestling  GER
# 29212     2008  Wrestling  LTU
# 29213     2008  Wrestling  ARM
# 29214     2008  Wrestling  CUB
# 29215     2008  Wrestling  RUS
#
# [29216 rows x 3 columns]

# %%
type(olympic_data[["Edition","Sport","NOC"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Using.object

# %%
olympic_data.Edition
# Out:
# 0        1896
# 1        1896
# 2        1896
# 3        1896
# 4        1896
#          ...
# 29211    2008
# 29212    2008
# 29213    2008
# 29214    2008
# 29215    2008
# Name: Edition, Length: 29216, dtype: int64

# %%
## we can access only one columns in data series

# %% [markdown]
# ## using : loc
# - String based index

# %%
olympic_data.loc[0:100,"Edition"]
# Out:
# 0      1896
# 1      1896
# 2      1896
# 3      1896
# 4      1896
#        ...
# 96     1896
# 97     1896
# 98     1896
# 99     1896
# 100    1896
# Name: Edition, Length: 101, dtype: int64

# %%
olympic_data.loc[0:100,["NOC","Edition","Sport"]]
# Out:
#      NOC  Edition       Sport
# 0    HUN     1896    Aquatics
# 1    AUT     1896    Aquatics
# 2    GRE     1896    Aquatics
# 3    GRE     1896    Aquatics
# 4    GRE     1896    Aquatics
# ..   ...      ...         ...
# 96   GRE     1896  Gymnastics
# 97   GRE     1896  Gymnastics
# 98   GRE     1896  Gymnastics
# 99   GER     1896  Gymnastics
# 100  GER     1896  Gymnastics
#
# [101 rows x 3 columns]

# %%
olympic_data.loc[0:100,"City":"Event"]
# Out:
#        City  Edition       Sport   Discipline               Athlete  NOC  \
# 0    Athens     1896    Aquatics     Swimming         HAJOS, Alfred  HUN
# 1    Athens     1896    Aquatics     Swimming      HERSCHMANN, Otto  AUT
# 2    Athens     1896    Aquatics     Swimming     DRIVAS, Dimitrios  GRE
# 3    Athens     1896    Aquatics     Swimming    MALOKINIS, Ioannis  GRE
# 4    Athens     1896    Aquatics     Swimming    CHASAPIS, Spiridon  GRE
# ..      ...      ...         ...          ...                   ...  ...
# 96   Athens     1896  Gymnastics  Artistic G.  KARVELAS, Phillippos  GRE
# 97   Athens     1896  Gymnastics  Artistic G.   LOUNDRAS, Dimitrios  GRE
# 98   Athens     1896  Gymnastics  Artistic G.  MITROPOULOS, Ioannis  GRE
# 99   Athens     1896  Gymnastics  Artistic G.        BÖCKER, Konrad  GER
# 100  Athens     1896  Gymnastics  Artistic G.        FLATOW, Alfred  GER
#
#     Gender                       Event
# 0      Men              100m freestyle
# ...

# %%
olympic_data.loc[0:100:2,"City":"Event":2]    # it include the last column and index
# Out:
#        City       Sport                            Athlete Gender
# 0    Athens    Aquatics                      HAJOS, Alfred    Men
# 2    Athens    Aquatics                  DRIVAS, Dimitrios    Men
# 4    Athens    Aquatics                 CHASAPIS, Spiridon    Men
# 6    Athens    Aquatics                      HAJOS, Alfred    Men
# 8    Athens    Aquatics              CHOROPHAS, Efstathios    Men
# 10   Athens    Aquatics                  PEPANOS, Antonios    Men
# 12   Athens   Athletics                   SZOKOLYI, Alajos    Men
# 14   Athens   Athletics                     HOFMANN, Fritz    Men
# 16   Athens   Athletics                 GOULDING, Grantley    Men
# 18   Athens   Athletics                       FLACK, Edwin    Men
# 20   Athens   Athletics                    GMELIN, Charles    Men
# 22   Athens   Athletics                   JAMISON, Herbert    Men
# 24   Athens   Athletics                       FLACK, Edwin    Men
# ...

# %% [markdown]
# ## using iloc
# - integer based, numerical index

# %%
olympic_data.iloc[0:100,0:3]    # it not included last column and
# Out:
#       City  Edition       Sport
# 0   Athens     1896    Aquatics
# 1   Athens     1896    Aquatics
# 2   Athens     1896    Aquatics
# 3   Athens     1896    Aquatics
# 4   Athens     1896    Aquatics
# ..     ...      ...         ...
# 95  Athens     1896  Gymnastics
# 96  Athens     1896  Gymnastics
# 97  Athens     1896  Gymnastics
# 98  Athens     1896  Gymnastics
# 99  Athens     1896  Gymnastics
#
# [100 rows x 3 columns]

# %%
olympic_data.iloc[0:100,2:3]
# Out:
#          Sport
# 0     Aquatics
# 1     Aquatics
# 2     Aquatics
# 3     Aquatics
# 4     Aquatics
# ..         ...
# 95  Gymnastics
# 96  Gymnastics
# 97  Gymnastics
# 98  Gymnastics
# 99  Gymnastics
#
# [100 rows x 1 columns]

# %%
type(olympic_data.iloc[0:100,2:3])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Challenge

# %% [markdown]
# ![image.png](attachment:75638be0-fd16-4f12-9588-2c88e9db29e4.png)

# %%
import pandas as pd
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv",skiprows=4)
olympic_data.head(1)
# Out:
#      City  Edition     Sport Discipline        Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming  HAJOS, Alfred  HUN    Men
#
#             Event Event_gender Medal
# 0  100m freestyle            M  Gold

# %%
# Q2
type(olympic_data["Edition"])
# Out:
# pandas.core.series.Series

# %%
type(olympic_data.Edition)
# Out:
# pandas.core.series.Series

# %%
#Q3
olympic_data[["Edition","City","Athlete","Medal"]]
# Out:
#        Edition     City               Athlete   Medal
# 0         1896   Athens         HAJOS, Alfred    Gold
# 1         1896   Athens      HERSCHMANN, Otto  Silver
# 2         1896   Athens     DRIVAS, Dimitrios  Bronze
# 3         1896   Athens    MALOKINIS, Ioannis    Gold
# 4         1896   Athens    CHASAPIS, Spiridon  Silver
# ...        ...      ...                   ...     ...
# 29211     2008  Beijing        ENGLICH, Mirko  Silver
# 29212     2008  Beijing  MIZGAITIS, Mindaugas  Bronze
# 29213     2008  Beijing       PATRIKEEV, Yuri  Bronze
# 29214     2008  Beijing         LOPEZ, Mijain    Gold
# 29215     2008  Beijing        BAROEV, Khasan  Silver
#
# [29216 rows x 4 columns]

# %%
type(olympic_data[["Edition","City","Athlete","Medal"]])
# Out:
# pandas.core.frame.DataFrame
